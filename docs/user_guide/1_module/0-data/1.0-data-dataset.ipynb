# %% [markdown]
# # Module - Data

# %%
# Import to be able to import python package from src
import sys
sys.path.insert(0, '../../../src')

# %%
from ontime.module.data.dataset import Dataset
# Out:
# The `LightGBM` module could not be imported. To enable LightGBM support in Darts, follow the detailed instructions in the installation guide: https://github.com/unit8co/darts/blob/master/INSTALL.md
# The `Prophet` module could not be imported. To enable Prophet support in Darts, follow the detailed instructions in the installation guide: https://github.com/unit8co/darts/blob/master/INSTALL.md

# %% [markdown]
# ### Get dataset reference
# Available datasets are referenced as static variables of the DatasetLoader class. The variable is a tuple of (dataset object, source library)

# %%
ds = Dataset.AirPassengersDataset 
print(ds)

# %% [markdown]
# ### Load the selected dataset

# %%
ts = ds.load() #loaded as a TimeSeries
ts.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
ds2 = Dataset.AMDStockPrices 
print(ds2)

# %%
ts2 = ds2.load() #loaded as a TimeSeries
ts2.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Est-ce que c'est la bonne signature

# %%
Benchmark(my_model_list, my_dataset_list)

# %% [markdown]
# DatasetList, est-ce qu'on en a vraiment besoin ou est-ce qu'une list serait suffisante?

# %%
MyDatasetList().add_dataset([
    Dataset.AMDStockPrices,
    TimeSeries
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 MyDatasetList().add_dataset([
#       2     Dataset.AMDStockPrices,
#       3 ])
#
# NameError: name 'MyDatasetList' is not defined

# %%
Dataset.load(my_dataset)
Dataset.my_dataset
Dataset.list()
