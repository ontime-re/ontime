# %% [markdown]
# # Module - Data

# %%
# Import to be able to import python package from src
import sys
sys.path.insert(0, '../../../src')

# %%
from ontime.module.datasets.dataset import Dataset

# %% [markdown]
# ### Get dataset reference
# Available datasets are referenced as static variables of the DatasetLoader class. The variable is a tuple of (dataset object, source library)

# %%
ds = Dataset.GasRateCO2Dataset 
print(ds)
# Out:
# <ontime.module.datasets.dataset.Dataset.DartsDataset object at 0x7fa2fcda3e50>

# %% [markdown]
# ### Load the selected dataset

# %%
ts = ds.load() #loaded as a TimeSeries
ts.plot()
# Out:
# alt.LayerChart(...)

# %%
ds2 = Dataset.HeartRateDataset 
print(ds2)
# Out:
# <ontime.module.datasets.dataset.Dataset.DartsDataset object at 0x7fa2fcda3d60>

# %%
ts2 = ds2.load() #loaded as a TimeSeries
ts2.plot()
# Out:
# alt.LayerChart(...)
