# %% [markdown]
# # Getting Started

# %%
# Import to be able to import python package from src
import sys
sys.path.insert(0, '../src')

# %%
import pandas as pd
import numpy as np
import ontime as on

# %% [markdown]
# ## Generation of random time series

# %%
def generate_random_time_series(start, end, freq='D'):
    date_rng = pd.date_range(start=start, end=end, freq=freq)
    random_data = np.random.randn(len(date_rng))
    ts = pd.DataFrame(random_data, index=date_rng, columns=['values'])
    return ts

# %%
ts = generate_random_time_series('2022-01-01', '2022-12-31')

# %%
ts
# Out:
#               values
# 2022-01-01 -0.405951
# 2022-01-02 -0.070564
# 2022-01-03 -2.264029
# 2022-01-04 -0.447855
# 2022-01-05  0.418300
# ...              ...
# 2022-12-27 -0.376309
# 2022-12-28  1.214681
# 2022-12-29 -1.949244
# 2022-12-30 -0.520153
# 2022-12-31 -0.326135
#
# [365 rows x 1 columns]

# %% [markdown]
# ## Use `TimeSeries` object

# %%
ts = on.TimeSeries.from_dataframe(ts)

# %%
ts.plot();

# %% [markdown]
# ---
# ## Test the creation of custom classes

# %% [markdown]
# ### Create custom model

# %%
from ontime.abstract import AbstractBaseModel

class MyModel(AbstractBaseModel):

    def __init__(self):
        super().__init__()

    def fit(self, series):
        super().fit(series)
        print('I am fitted')

    def predict(self, horizon):
        super().predict(horizon)
        print('I see the horizon')

# %% [markdown]
# Load custom model in OnTime

# %%
on.models.get_all()
# Out:
# []

# %%
on.models.load('my_model', MyModel) 
on.models.get_all()
# Out:
# ['my_model']

# %%
on.models.my_model.predict(ts)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 on.models.my_model.predict(ts)
#
# Cell In[8], line 13, in MyModel.predict(self, horizon)
#      12 def predict(self, horizon):
# ---> 13     super().predict(horizon)
#      14     print('I see the horizon')
#
# File ~/src/ontime/notebooks/../src/ontime/abstract/abstract_base_model.py:25, in AbstractBaseModel.predict(self, horizon)
#      23 """ Usage of the model to predict values """
#      24 if self._is_fitted is False:
# ---> 25     raise Exception('fit() must be called before predict()')
#
# Exception: fit() must be called before predict()

# %%
on.models.my_model.fit(ts)
# Out:
# I am fitted

# %%
on.models.my_model.predict(ts)
# Out:
# I see the horizon

# %% [markdown]
# ### Create custom detector

# %%
from ontime.abstract import AbstractBaseDetector

class MyDetector(AbstractBaseDetector):

    def __init__(self):
        super().__init__()

    def detect(self, ts):
        print('I detected')

# %% [markdown]
# Load custom detector in OnTime

# %%
on.detectors.get_all()
# Out:
# []

# %%
on.detectors.load('my_detector', MyDetector)

# %%
on.detectors.get_all()
# Out:
# ['my_detector']

# %%
on.detectors.my_detector.detect(ts)
# Out:
# I detected
